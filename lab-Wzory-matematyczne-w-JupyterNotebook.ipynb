# %% [markdown]
# # Ćwiczenia: Tworzenie wzorów matematycznych w Jupyter Notebook
#
# * Krzysztof Molenda, 3.03.2026
#
# Witaj! Ten notatnik ma na celu pomóc Ci w opanowaniu składni $LaTeX$ do tworzenia czytelnych i profesjonalnych wzorów matematycznych.
#
# **Instrukcja dla studenta:**
# - Aby zobaczyć kod wzoru w przykładzie, kliknij dwukrotnie w wybraną komórkę.
# - Aby zatwierdzić komórkę i wyrenderować wzór, naciśnij `Shift + Enter`.
# - Wykonaj zadania w oznaczonych komórkach, próbując odwzorować podane w poleceniu wzory.

# %% [markdown]
# ## 1. Podstawowe operacje: ułamki, potęgi i indeksy
#
# **Przykład:**
# Wzory matematyczne można umieszczać w tekście używając pojedynczych znaków dolara (np. $x^2$), lub w osobnych, wyśrodkowanych liniach używając podwójnych znaków dolara `$$`.
#
# $$ f(x) = \frac{x^2 + 2x_i}{y_{i+1} - 1} $$

# %% [markdown]
# **Ćwiczenie 1:**
# Napisz poniżej (w nowej linii, wyśrodkowane za pomocą `$$`) słynny wzór na pierwiastki równania kwadratowego (tzw. deltę).
#
# Wskazówki:
# - Użyj `\pm` dla znaku plus-minus ($\pm$).
# - Użyj `\sqrt{}` dla pierwiastka kwadratowego.
# - Użyj `\frac{}{}` dla ułamka.
#
# *Twój wzór wpisz poniżej:*

# %% [markdown]
# ## 2. Granice, sumy i całki
#
# **Przykład:**
# Operatory takie jak granica (`\lim`), suma (`\sum`) czy całka (`\int`) często posiadają dolne i górne granice, które zapisujemy używając `_` oraz `^`.
#
# $$ \lim_{n \to \infty} \sum_{k=1}^n \frac{1}{k^2} = \frac{\pi^2}{6} $$
#
# $$ \int_{0}^{\pi} \sin(x) dx = 2 $$

# %% [markdown]
# **Ćwiczenie 2:**
# Napisz poniżej wzór na definicję pochodnej funkcji $f$ w punkcie $x_0$.
#
# Wskazówki:
# - Granica przy $h$ dążącym do $0$ to `\lim_{h \to 0}`.
# - Pamiętaj o ułamku `\frac{f(x_0 + h) - f(x_0)}{h}`.
#
# *Twój wzór wpisz poniżej:*

# %% [markdown]
# ## 3. Macierze i układy równań
#
# **Przykład:**
# Do macierzy używamy środowiska `\begin{pmatrix} ... \end{pmatrix}` (nawiasy okrągłe) lub `bmatrix` (nawiasy kwadratowe). Kolumny oddzielamy znakiem `&`, a wiersze podwójnym backslashem `\\`.
#
# $$ A = \begin{bmatrix} a_{11} & a_{12} \\ a_{21} & a_{22} \end{bmatrix} $$

# %% [markdown]
# **Ćwiczenie 3:**
# Napisz poniżej macierz jednostkową $I$ o wymiarach 3x3 (zawierającą jedynki na głównej przekątnej i zera w pozostałych miejscach). Użyj zwykłych nawiasów okrągłych (`pmatrix`).
#
# *Twój wzór wpisz poniżej:*

# %% [markdown]
# ## 4. Greckie litery i przydatne symbole
#
# **Przykład:**
# Greckie litery to ich nazwy poprzedzone backslashem: `\alpha`, `\beta`, `\Gamma`, `\Delta`.
#
# $$ \sin^2(\theta) + \cos^2(\theta) = 1 $$

# %% [markdown]
# **Ćwiczenie 4:**
# Napisz tożsamość Eulera: $e$ do potęgi ($i$ razy $\pi$) plus jeden równa się zero.
#
# Wskazówka: Do wpisania liczby pi ($\pi$) użyj `\pi`.
#
# *Twój wzór wpisz poniżej:*

# %% [markdown]
# ## 5. Zadania

# %% [markdown]
# Zapisz wzory, używając notacji $LaTeX$

# %% [markdown]
# <img src="data:image/png;base64,..." alt="Ułamek łańcuchowy">

# %% [markdown]
# <img src="data:image/png;base64,...">
